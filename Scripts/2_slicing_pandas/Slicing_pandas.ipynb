# %%
# librerias y documentacion 
# Series de pandas 
# Como se compone un dataframe 
# Crear un Serie desde diccionario
# Cromo crear una columna / serie con una lista

# %%
# pandas 
# numpy 
# Spicy
# Sklearn , pycaret
# tensorflow, pythorch ,phopeth

# %%
import pandas as pd
#trae la ca ja de herramientas pandas y apodalo pd
df=pd.read_csv(r"C:\Users\jacj2\OneDrive\Desktop\clases_personalizadas\Scripts\slicing_pandas\corte_pandas.csv")

# %%
# que tamaño tien el df 
df.shape
# tupla(filas ,columnas)
# Out:
# (9, 4)

# %%
#slicing indice es la posicion
# las posiciones en python siempre inician en 0 de iqz a derech
df.shape[1]
# Out:
# 4

# %%
# atributo para ver por primeros 5 elementos 
df.head()
# Out:
#    Seleccion  Unos   aleatorio  aleatorio1
# 0          0      0          1           0
# 1          0      0          1           0
# 2          0      1          1           0
# 3          0      1          1           0
# 4          0      1          1           0

# %%
df.head(9)
# Out:
#    Seleccion  Unos   aleatorio  aleatorio1
# 0          0      0          1           0
# 1          0      0          1           0
# 2          0      1          1           0
# 3          0      1          1           0
# 4          0      1          1           0
# 5          0      1          1           0
# 6          0      1          1           0
# 7          0      0          0           0
# 8          0      0          0           0

# %%
#index localizer ( localizador de indices)
#dataframe.iloc[  Desde columna : Hasta columna,desde fila : Hasta fila  ]
df.iloc[:2,2]
# Out:
# 0    1
# 1    1
# Name: aleatorio, dtype: int64

# %%
df.iloc[2:7,1:3]
# Out:
#    Unos   aleatorio
# 2      1          1
# 3      1          1
# 4      1          1
# 5      1          1
# 6      1          1

# %%
df.iloc[7:,:]
# Out:
#    Seleccion  Unos   aleatorio  aleatorio1
# 7          0      0          0           0
# 8          0      0          0           0

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.Seleccion)
# Out:
# pandas.core.series.Series

# %%
type([1,2,3])
# Out:
# list

# %%
lista_ejemplo=[1,2,3]

# %%
type(lista_ejemplo)
# Out:
# list

# %%
serie1=pd.Series(lista_ejemplo)

# %%
serie2=pd.Series([9,8,7])

# %%
pd.DataFrame({"ejemplo_serie1":lista_ejemplo,
              "Segundo_elemento":[9,8,7]})
# Out:
#    ejemplo_serie1  Segundo_elemento
# 0               1                 9
# 1               2                 8
# 2               3                 7

# %%
pd.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
opreaciones=pd.read_csv(r"C:\Users\jacj2\OneDrive\Desktop\clases_personalizadas\Scripts\slicing_pandas\aperaciones_pandas.csv")

# %%
opreaciones.shape[0]*opreaciones.shape[1]
# Out:
# 2000

# %%
opreaciones.columns
# Out:
# Index(['Seleccion', 'Unos ', 'aleatorio', 'aleatorio1'], dtype='object')

# %%
opreaciones.sum()
# Out:
# Seleccion     251.076422
# Unos          248.415141
# aleatorio     247.431788
# aleatorio1    245.215193
# dtype: float64

# %%
opreaciones.sum(axis=1)
# Out:
# 0      1.336195
# 1      1.836918
# 2      2.115696
# 3      1.399362
# 4      2.939399
#          ...
# 495    2.877892
# 496    2.435129
# 497    1.538606
# 498    2.601985
# 499    2.892969
# Length: 500, dtype: float64

# %%
opreaciones.sum(axis=0)
# Out:
# Seleccion     251.076422
# Unos          248.415141
# aleatorio     247.431788
# aleatorio1    245.215193
# dtype: float64

# %%
import matplotlib.pyplot as plt
for i in df.columns:
    opreaciones[i].plot()
    plt.show()

# %%
numpy

# %%
graficas
